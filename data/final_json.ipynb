# %%
import pandas as pd
import csv, requests, os, re, itertools, codecs
from tqdm import tqdm
from time import sleep
import simplejson as json

# %% [markdown]
# ### Load data and get list of all countries

# %%
airrights = pd.read_csv('flight_rights_unicities.tsv', sep='\t')
treaties = pd.read_csv('treaties_unicities.tsv', sep='\t')
schedules = pd.read_csv('allschedules_unicities.tsv', sep='\t')

countries = (treaties.encountry.values.tolist() +
             airrights.encountry.values.tolist() +
             schedules.encountry_from.values.tolist() +
             schedules.encountry_to.values.tolist())

countries = sorted(list(set(countries)), key=str.lower)

# %% [markdown]
# ### Get dictionary (*pythonic json* XD) of all countries
#
# **Structure**:
#
# + country treaty:
#     * date,
#     * status,
#     * url for rada page
#     - conditions within the treaty
#         * points in English & Ukrainian
#         * comment (empty if no comments)
#         - limits of number of airlines that can exploit all routes in country(scope 'condition')
#         or per route (scope 'point')
#             * limit - number of airlines
#             * scope - condition or per route
#         - flight limits: how many flights can be done within scope
#             * limit,
#             * scope - condition in general, per point, per airline
#         - permissions to fly for Ukrainian companies, given according to treaty condition
#             * points in Ukraine and other country
#             * permission id, date when received, No of protocol etc
#             * airline
#             * maximum flight frequency for airline on route
#             * how many flights are scheduled per week **! not all schedules are awailable**
#             * flight numbers of sheduled flights (**possible link to google flights???**)

# %%
country_dicts = []

for country in countries:
    if country == 'Ukraine':
        continue
    
    treaties_c = treaties.loc[treaties.encountry == country, :].fillna('')
    airrights_c = airrights.loc[airrights.encountry == country, :].fillna('')
    schedules_c = schedules.loc[((schedules.encountry_from == country) |
                                 (schedules.encountry_to == country)), :].fillna('')
    
# ---make the most restricted conditions in treaty appear first, and condition for all - last.
# otherwise all given rights will belong to the last condition for all rest points---
    treaties_c['sort'] = (treaties_c.encities_ua == 'all').astype(int)
    treaties_c['sort'] += (treaties_c.encities_foreign == 'all').astype(int)
    treaties_c.sort_values(by='sort', inplace=True)
    
# ---in treaties if condition is full, replace 'all' to country name or 'other'---
    
    if treaties_c.encities_foreign.str.contains('all').sum() < len(treaties_c):
        treaties_c.loc[treaties_c.encities_foreign.str.contains('all'), 'encities_foreign'] = 'other'
        treaties_c.loc[treaties_c.cities_foreign.str.contains('всі'), 'cities_foreign'] = 'інші'
    else:
        treaties_c.loc[treaties_c.encities_foreign.str.contains('all'), 'encities_foreign'] = country
        treaties_c.loc[treaties_c.cities_foreign.str.contains('всі'), 'cities_foreign'] = treaties_c.country.iloc[0]

# replace for Ukrainian points
    if treaties_c.encities_ua.str.contains('all').sum() < len(treaties_c):
        treaties_c.loc[treaties_c.encities_ua.str.contains('all'), 'encities_ua'] = 'other'
        treaties_c.loc[treaties_c.cities_ua.str.contains('всі'), 'cities_ua'] = 'інші'
    else:
        treaties_c.loc[treaties_c.encities_ua.str.contains('all'), 'encities_ua'] = 'Ukraine'
        treaties_c.loc[treaties_c.cities_ua.str.contains('всі'), 'cities_ua'] = 'Україна'
    
# ---initialize country dictionary---
    country_dict = {
        'encoutry': country,
        'treaty':{
            'conditions': []
        }
    }
    
    country_dict['treaty']['uacountry'] = treaties_c.country.iloc[0]
    country_dict['treaty']['date'] = treaties_c.date.iloc[0]
    country_dict['treaty']['url'] = treaties_c.url.iloc[0]
    country_dict['treaty']['stage'] = treaties_c.stage.iloc[0]

    chosen_ids = [] # to prevent more specified conditions from being selected to general ones

# ---Find flight permissions for every treaty---
    for i, condition in enumerate(treaties_c.to_dict(orient='records')):
        
#     new condition dict           
        new_condition = {
            'ua_from': condition['cities_ua'],
            'en_from': condition['encities_ua'],
            'ua_to': condition['cities_foreign'],
            'en_to': condition['encities_foreign'],
            'comment': condition['comments'],
            'flight_limits': [],
            'airline_limits': [],
            'permissions': []
        }
        
# add scope to limits
#         scopes: 
#             - condition: general limit of flights within condition
#             - point: limit of flights to each point
#             - airline: limit of flights for every airline
        
        if condition['airlines_total'] != 999:
            new_condition['airline_limits'].append({'limit': condition['airlines_total'], 'scope': 'condition'})
            
        if (condition['airlines_route'] != 999
            and condition['airlines_route'] != condition['airlines_total']):
            new_condition['airline_limits'].append({'limit': condition['airlines_route'], 'scope': 'point'})
            
        if condition['fw_gen'] != 999:
            new_condition['flight_limits'].append({'limit': condition['fw_gen'], 'scope': 'condition'})
            
        if (condition['fw_route'] != 999
            and condition['fw_route'] != condition['fw_gen']):
            new_condition['flight_limits'].append({'limit': condition['fw_route'], 'scope': 'point'})
            
        if (condition['fw_airline'] != 999
            and condition['fw_airline'] != condition['fw_gen']
            and condition['fw_airline'] != condition['fw_route']):
            new_condition['flight_limits'].append({'limit': condition['fw_airline'], 'scope': 'airline'})
        
        
        encities_ua = condition['encities_ua'] if condition['encities_ua'] != 'all' else '.'
        encities_foreign = condition['encities_foreign'] if condition['encities_foreign'] != 'all' else '.'

        condition_rights = airrights_c.loc[ airrights_c.from_encity.str.contains(encities_ua) &
                                            airrights_c.to_encity.str.contains(encities_foreign) &
                                            ~ airrights_c.right_id.isin(chosen_ids), ] 
        
# add chosen rights to list of all chosen fly permissions
        chosen_ids += condition_rights.right_id.values.tolist()

        condition_rights = condition_rights.to_dict(orient='records')

# ---from schedules select flights, that are made according to this rule and fill to dict---
        for i, right in enumerate(condition_rights):
            right_schedule = schedules_c.loc[((schedules_c.airline.str.contains(right['iata_airline']) |
                                                schedules_c.airline.str.contains(right['icao_airline'])) &
                                               (schedules_c.encity_from.str.contains(right['from_encity']) |
                                                schedules_c.encity_from.str.contains(right['to_encity'])) &
                                               (schedules_c.encity_to.str.contains(right['from_encity']) |
                                                schedules_c.encity_to.str.contains(right['to_encity']))), ]

# add info about total # of route flights and flight numbers within this right
            if len(list(set(right_schedule.flight.values.tolist()))) > 0:
                condition_rights[i]['schedules'] = {
                    'freq': right_schedule.days_week.apply(lambda x: len(str(x))).drop_duplicates().sum(),
                    'flights': list(set(right_schedule.flight.values.tolist()))
                }

        new_condition['permissions'] = condition_rights
                
# ---add conditions to countrydict---
        country_dict['treaty']['conditions'].append(new_condition)
    
# --- append country pre-json to overall one
    country_dicts.append(country_dict)

# %% [markdown]
# **! Attention ! The code below rewrites json file**
# - Use it wise and #comment after usage

# %%
# with codecs.open('C:/Users/Nadya/Desktop/aviaroutes/avia_table.json', 'w', encoding='utf-8') as f:
#     f.write(json.dumps(country_dicts))

# %%
country_dicts
# Out:
# [{'encoutry': 'Albania',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Kiev',
#      'en_to': 'Tirana',
#      'flight_limits': [{'limit': 7, 'scope': 'condition'}],
#      'permissions': [{'airline_name': 'Браво',
#        'annul_date': '',
#        'annul_reason': '',
#        'country': 'Республіка Албанія',
#        'date': '02.03.2017',
#        'encountry': 'Albania',
#        'from_city': 'Київ',
#        'from_encity': 'Kiev',
#        'given_by': 'Протокол засідання комісії ДАС № 22 від 27.02.2017',
#        'given_date': '03.03.2017',
#        'iata_airline': '',
#        'icao_airline': 'BAY',
#        'max_freq': '2',
#        'min_freq': 0,
#        'right_id': 1859,
#        'to_city': 'Тірана',
#        'to_encity': 'Tirana',
#        'type_of_right': 'Регулярні міжнародні',
#        'valid_from': '26.03.2017',
#        'valid_till': '26.10.2067'},
#       {'airline_name': 'ДАРТ',
#        'annul_date': '',
#        'annul_reason': '',
#        'country': 'Республіка Албанія',
#        'date': '06.05.2016',
#        'encountry': 'Albania',
#        'from_city': 'Київ',
#        'from_encity': 'Kiev',
#        'given_by': 'Протокол засідання комісії ДАС № 12 від 28.04.2016',
#        'given_date': '10.05.2016',
#        'iata_airline': 'D4',
#        'icao_airline': 'DAT',
#        'max_freq': '7',
#        'min_freq': 0,
#        'right_id': 1429,
#        'to_city': 'Тірана',
#        'to_encity': 'Tirana',
#        'type_of_right': 'Регулярні міжнародні',
#        'valid_from': '16.05.2016',
#        'valid_till': '16.05.2065'},
#       {'airline_name': 'Дніпроавіа',
#        'annul_date': '',
#        'annul_reason': '',
#        'country': 'Республіка Албанія',
#        'date': '30.12.2015',
#        'encountry': 'Albania',
#        'from_city': 'Київ',
#        'from_encity': 'Kiev',
#        'given_by': 'Протокол засідання комісії ДАС №8 від 30.12.2015',
#        'given_date': '31.12.2015',
#        'iata_airline': 'Z6',
#        'icao_airline': 'UDN',
#        'max_freq': '7',
#        'min_freq': 0,
#        'right_id': 1253,
#        'to_city': 'Тірана',
#        'to_encity': 'Tirana',
#        'type_of_right': 'Регулярні міжнародні',
#        'valid_from': '01.01.2016',
#        'valid_till': '31.12.2025'}],
#      'ua_from': 'Київ',
#      'ua_to': 'Тирана'}],
#    'date': '',
#    'stage': 'проект',
#    'uacountry': 'Албанія',
#    'url': ''}},
#  {'encoutry': 'Armenia',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Armenia',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Вірменія'}],
#    'date': '11.08.1995',
#    'stage': 'чинна',
#    'uacountry': 'Вірменія',
#    'url': 'http://zakon2.rada.gov.ua/laws/show/051_016'}},
#  {'encoutry': 'Austria',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Austria',
#      'flight_limits': [{'limit': 14, 'scope': 'point'}],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Австрія'}],
#    'date': '01.12.1994',
#    'stage': 'чинна',
#    'uacountry': 'Австрія',
#    'url': 'http://zakon3.rada.gov.ua/laws/show/040_001'}},
#  {'encoutry': 'Azerbaijan',
#   'treaty': {'conditions': [{'airline_limits': [{'limit': 1,
#        'scope': 'point'}],
#      'comment': '',
#      'en_from': 'Odessa--Lviv',
#      'en_to': 'Lankaran',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Одеса--Львів',
#      'ua_to': 'Лінкорань'},
#     {'airline_limits': [{'limit': 1, 'scope': 'point'}],
#      'comment': '',
#      'en_from': 'other',
#      'en_to': 'other',
#      'flight_limits': [{'limit': 14, 'scope': 'point'}],
#      'permissions': [],
#      'ua_from': 'інші',
#      'ua_to': 'інші'}],
#    'date': '30.01.1996',
#    'stage': 'чинна',
#    'uacountry': 'Азербайджан',
#    'url': 'http://zakon2.rada.gov.ua/laws/show/031_059'}},
#  {'encoutry': 'Bahrain',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Kiev',
#      'en_to': 'Bahrain',
#      'flight_limits': [{'limit': 14, 'scope': 'condition'}],
#      'permissions': [],
#      'ua_from': 'Київ',
#      'ua_to': 'Бахрейн'},
#     {'airline_limits': [],
#      'comment': '',
#      'en_from': 'other',
#      'en_to': 'other',
#      'flight_limits': [{'limit': 7, 'scope': 'condition'}],
#      'permissions': [],
#      'ua_from': 'інші',
#      'ua_to': 'інші'}],
#    'date': '',
#    'stage': 'парафована',
#    'uacountry': 'Бахрейн',
#    'url': ''}},
#  {'encoutry': 'Belarus',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': 'Умова діє у літній сезон IATA',
#      'en_from': 'Kiev',
#      'en_to': 'Minsk',
#      'flight_limits': [{'limit': 35, 'scope': 'condition'}],
#      'permissions': [{'airline_name': 'МАУ',
#        'annul_date': '',
#        'annul_reason': '',
#        'country': 'Республіка Білорусь',
#        'date': '06.05.2016',
#        'encountry': 'Belarus',
#        'from_city': 'Київ',
#        'from_encity': 'Kiev',
#        'given_by': 'Протокол засідання комісії ДАС № 12 від 28.04.2016',
#        'given_date': '10.05.2016',
#        'iata_airline': 'PS',
#        'icao_airline': 'AUI',
#        'max_freq': '21',
#        'min_freq': 0,
#        'right_id': 644,
#        'schedules': {'flights': ['PS891',
#          'PS893',
#          'PS894',
#          'B2844',
#          'PS892',
#          'PS889'],
#         'freq': 14},
#        'to_city': 'Мінськ',
#        'to_encity': 'Minsk',
#        'type_of_right': 'Регулярні міжнародні',
#        'valid_from': '22.11.2013',
#        'valid_till': ''}],
#      'ua_from': 'Київ',
#      'ua_to': 'Мінськ'},
#     {'airline_limits': [],
#      'comment': '',
#      'en_from': 'other',
#      'en_to': 'other',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'інші',
#      'ua_to': 'інші'}],
#    'date': '19.09.1995',
#    'stage': 'чинна',
#    'uacountry': 'Білорусь',
#    'url': 'http://zakon2.rada.gov.ua/laws/show/112_028?nreg=112_028&find=1&text=%EB%B3%F2%EE&x=0&y=0'}},
#  {'encoutry': 'Belgium',
#   'treaty': {'conditions': [{'airline_limits': [{'limit': 1,
#        'scope': 'condition'}],
#      'comment': 'Частоти узгоджуються в робочому порядку',
#      'en_from': 'Ukraine',
#      'en_to': 'Belgium',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Бельгія'}],
#    'date': '01.01.2003',
#    'stage': 'чинна',
#    'uacountry': 'Бельгія',
#    'url': 'http://zakon2.rada.gov.ua/laws/show/056_013'}},
#  {'encoutry': 'Bosnia and Herzegovina',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Kiev',
#      'en_to': 'Bosnia and Herzegovina',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Київ',
#      'ua_to': 'Боснія і Герцеговина'}],
#    'date': '17.12.2009',
#    'stage': 'чинна',
#    'uacountry': 'Боснія і Герцеговина',
#    'url': ''}},
#  {'encoutry': 'Brazil',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Brazil',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Бразилія'}],
#    'date': '02.12.2009',
#    'stage': 'підписана',
#    'uacountry': 'Бразилія',
#    'url': 'http://zakon2.rada.gov.ua/laws/show/076_025'}},
#  {'encoutry': 'Bulgaria',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Bulgaria',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Болгарія'}],
#    'date': '14.04.1995',
#    'stage': 'чинна',
#    'uacountry': 'Болгарія',
#    'url': ''}},
#  {'encoutry': 'Canada',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': 'Другий пункт (крім Торонто) може змінюватись кожного періоду ІАТА',
#      'en_from': 'Ukraine',
#      'en_to': 'Toronto--NA',
#      'flight_limits': [{'limit': 3, 'scope': 'point'}],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Торонто--NA'}],
#    'date': '28.04.1999',
#    'stage': 'чинна',
#    'uacountry': 'Канада',
#    'url': ''}},
#  {'encoutry': 'China',
#   'treaty': {'conditions': [{'airline_limits': [{'limit': 3,
#        'scope': 'condition'}],
#      'comment': 'Додатково 1 вантажний рейс з України до Тяньцзіня',
#      'en_from': 'Ukraine',
#      'en_to': 'Beijing--Tianjin--Shanghai--Guangzhou',
#      'flight_limits': [{'limit': 14, 'scope': 'condition'},
#       {'limit': 7, 'scope': 'point'}],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Пекін--Тяньцзінь--Шанхай--Гуанчжоу'}],
#    'date': '05.07.1993',
#    'stage': 'чинна',
#    'uacountry': 'КНР',
#    'url': 'http://zakon2.rada.gov.ua/laws/show/156_051'}},
#  {'encoutry': 'Croatia',
#   'treaty': {'conditions': [{'airline_limits': [{'limit': 1,
#        'scope': 'point'}],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Croatia',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Хорватія'}],
#    'date': '09.12.2002',
#    'stage': 'чинна',
#    'uacountry': 'Хорватія',
#    'url': 'http://zakon2.rada.gov.ua/laws/show/191_011'}},
#  {'encoutry': 'Cuba',
#   'treaty': {'conditions': [{'airline_limits': [{'limit': 2,
#        'scope': 'condition'},
#       {'limit': 1, 'scope': 'point'}],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Cuba',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Куба'}],
#    'date': '08.01.2001',
#    'stage': 'чинна',
#    'uacountry': 'Куба',
#    'url': 'http://zakon3.rada.gov.ua/laws/show/192_013'}},
#  {'encoutry': 'Cyprus',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Larnaca--Paphos',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Ларнака--Пафос'}],
#    'date': '08.11.2012',
#    'stage': 'підписана',
#    'uacountry': 'Кіпр',
#    'url': 'http://zakon2.rada.gov.ua/laws/show/196_024'}},
#  {'encoutry': 'Czech Republic',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Kiev',
#      'en_to': 'Prague',
#      'flight_limits': [{'limit': 10, 'scope': 'condition'}],
#      'permissions': [{'airline_name': 'МАУ',
#        'annul_date': '',
#        'annul_reason': '',
#        'country': 'Чеська Республіка',
#        'date': '28.08.2015',
#        'encountry': 'Czech Republic',
#        'from_city': 'Київ',
#        'from_encity': 'Kiev',
#        'given_by': 'Протокол засідання комісії ДАС №4 від 28.08.2015',
#        'given_date': '28.08.2015',
#        'iata_airline': 'PS',
#        'icao_airline': 'AUI',
#        'max_freq': '17',
#        'min_freq': 0,
#        'right_id': 607,
#        'schedules': {'flights': ['PS807', 'PS809', 'PS808', 'PS810'],
#         'freq': 8},
#        'to_city': 'Прага',
#        'to_encity': 'Prague',
#        'type_of_right': 'Регулярні міжнародні',
#        'valid_from': '20.09.2013',
#        'valid_till': ''}],
#      'ua_from': 'Київ',
#      'ua_to': 'Прага'},
#     {'airline_limits': [],
#      'comment': '7 р/т за кожним маршрутом сукупно для українських і чеських а/к ',
#      'en_from': 'Odessa--Donetsk--Lviv--Kharkiv--Simferopol--Ужгород--Dnipro',
#      'en_to': 'Prague',
#      'flight_limits': [{'limit': 4, 'scope': 'point'}],
#      'permissions': [],
#      'ua_from': 'Одеса--Донецьк--Львів--Харків--Сімферополь--Ужгород--Дніпро',
#      'ua_to': 'Прага'},
#     {'airline_limits': [],
#      'comment': '7 р/т за кожним маршрутом сукупно для українських і чеських а/к ',
#      'en_from': 'Kiev',
#      'en_to': 'Karlovy Vary',
#      'flight_limits': [{'limit': 4, 'scope': 'condition'}],
#      'permissions': [],
#      'ua_from': 'Київ',
#      'ua_to': 'Карлови Вари'}],
#    'date': '09.09.1998',
#    'stage': 'чинна',
#    'uacountry': 'Чехія',
#    'url': 'http://zakon3.rada.gov.ua/laws/show/203_038'}},
#  {'encoutry': 'Denmark',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Copenhagen--NA--NA',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Копенгаген--NA--NA'}],
#    'date': '27.03.2001',
#    'stage': 'чинна',
#    'uacountry': 'Данія',
#    'url': 'http://zakon2.rada.gov.ua/laws/show/208_010'}},
#  {'encoutry': 'Egypt',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Kiev',
#      'en_to': 'Cairo',
#      'flight_limits': [{'limit': 4, 'scope': 'condition'}],
#      'permissions': [{'airline_name': 'МАУ',
#        'annul_date': '',
#        'annul_reason': '',
#        'country': 'Арабська Республіка Єгипет',
#        'date': '01.09.2016',
#        'encountry': 'Egypt',
#        'from_city': 'Київ',
#        'from_encity': 'Kiev',
#        'given_by': 'Протокол засідання комісії ДАС № 16 від 30.08.2016',
#        'given_date': '01.09.2016',
#        'iata_airline': 'PS',
#        'icao_airline': 'AUI',
#        'max_freq': '4',
#        'min_freq': 0,
#        'right_id': 1523,
#        'to_city': 'Каїр',
#        'to_encity': 'Cairo',
#        'type_of_right': 'Регулярні міжнародні',
#        'valid_from': '01.09.2016',
#        'valid_till': '01.09.2066'}],
#      'ua_from': 'Київ',
#      'ua_to': 'Каїр'},
#     {'airline_limits': [],
#      'comment': 'Обмеження ємності 450 крісел/тиждень у кожному напрямку',
#      'en_from': 'other',
#      'en_to': 'other',
#      'flight_limits': [{'limit': 4, 'scope': 'condition'}],
#      'permissions': [],
#      'ua_from': 'інші',
#      'ua_to': 'інші'}],
#    'date': '22.12.1993',
#    'stage': 'чинна',
#    'uacountry': 'Єгипет',
#    'url': 'http://zakon2.rada.gov.ua/laws/show/818_004'}},
#  {'encoutry': 'Estonia',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Estonia',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Естонія'}],
#    'date': '16.09.1993',
#    'stage': 'чинна',
#    'uacountry': 'Естонія',
#    'url': 'http://zakon2.rada.gov.ua/laws/show/233_012'}},
#  {'encoutry': 'Finland',
#   'treaty': {'conditions': [{'airline_limits': [{'limit': 1,
#        'scope': 'point'}],
#      'comment': '',
#      'en_from': 'Kiev',
#      'en_to': 'Helsinki--Enontekio--Ivalo--Kemi--Kittila--Rovaniemi',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Київ',
#      'ua_to': 'HEL--ENF--IVL--KEM--KTT--RVN'}],
#    'date': '01.03.1996',
#    'stage': 'чинна',
#    'uacountry': 'Фінляндія',
#    'url': 'http://zakon3.rada.gov.ua/laws/show/246_023'}},
#  {'encoutry': 'France',
#   'treaty': {'conditions': [{'airline_limits': [{'limit': 1,
#        'scope': 'condition'}],
#      'comment': '',
#      'en_from': 'Kiev',
#      'en_to': 'Paris',
#      'flight_limits': [{'limit': 14, 'scope': 'condition'}],
#      'permissions': [{'airline_name': 'МАУ',
#        'annul_date': '',
#        'annul_reason': '',
#        'country': 'Французька Республіка',
#        'date': '31.01.2014',
#        'encountry': 'France',
#        'from_city': 'Київ',
#        'from_encity': 'Kiev',
#        'given_by': 'Протокол засідання комісії МІУ № 11 від 31.01.2014',
#        'given_date': '20.02.2014',
#        'iata_airline': 'PS',
#        'icao_airline': 'AUI',
#        'max_freq': '14',
#        'min_freq': 0,
#        'right_id': 569,
#        'schedules': {'flights': ['PS9283',
#          'PS9282',
#          'PS129',
#          'PS127',
#          'PS9263',
#          'PS130',
#          'PS128',
#          'PS9262'],
#         'freq': 7},
#        'to_city': 'Париж',
#        'to_encity': 'Paris',
#        'type_of_right': 'Регулярні міжнародні',
#        'valid_from': '20.09.2013',
#        'valid_till': '20.09.2023'}],
#      'ua_from': 'Київ',
#      'ua_to': 'Париж'},
#     {'airline_limits': [{'limit': 1, 'scope': 'condition'}],
#      'comment': '',
#      'en_from': 'other',
#      'en_to': 'other',
#      'flight_limits': [{'limit': 7, 'scope': 'point'}],
#      'permissions': [],
#      'ua_from': 'інші',
#      'ua_to': 'інші'}],
#    'date': '23.01.1995',
#    'stage': 'чинна',
#    'uacountry': 'Франція',
#    'url': 'http://zakon3.rada.gov.ua/laws/show/250_051'}},
#  {'encoutry': 'Georgia',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Georgia',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Грузія'}],
#    'date': '11.11.2011',
#    'stage': 'чинна',
#    'uacountry': 'Грузія',
#    'url': 'http://zakon2.rada.gov.ua/laws/show/268_108'}},
#  {'encoutry': 'Germany',
#   'treaty': {'conditions': [{'airline_limits': [{'limit': 2,
#        'scope': 'point'}],
#      'comment': '',
#      'en_from': 'Kiev',
#      'en_to': 'Berlin--Frankfurt--Munich',
#      'flight_limits': [{'limit': 28, 'scope': 'condition'}],
#      'permissions': [],
#      'ua_from': 'Київ',
#      'ua_to': 'Берлін--Франкфурт--Мюнхен'},
#     {'airline_limits': [{'limit': 3, 'scope': 'point'}],
#      'comment': 'на всі рейси з/до Києва можуть ути призначені до 2-х авіакомпаній',
#      'en_from': 'other',
#      'en_to': 'other',
#      'flight_limits': [{'limit': 7, 'scope': 'condition'}],
#      'permissions': [],
#      'ua_from': 'інші',
#      'ua_to': 'інші'}],
#    'date': '15.03.1999',
#    'stage': 'чинна',
#    'uacountry': 'Німеччина',
#    'url': 'http://zakon.rada.gov.ua/laws/show/276_044'}},
#  {'encoutry': 'Greece',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Greece',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Греція'}],
#    'date': '06.10.2011',
#    'stage': 'підписана',
#    'uacountry': 'Греція',
#    'url': 'http://zakon2.rada.gov.ua/laws/show/300_028'}},
#  {'encoutry': 'Hong Kong',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Hong Kong',
#      'flight_limits': [{'limit': 7, 'scope': 'point'}],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Гонконг'}],
#    'date': '',
#    'stage': 'проект',
#    'uacountry': 'Гонконг',
#    'url': ''}},
#  {'encoutry': 'Hungary',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '+9 вантажних рейсів ',
#      'en_from': 'Kiev--Odessa',
#      'en_to': 'Budapest',
#      'flight_limits': [{'limit': 9, 'scope': 'condition'}],
#      'permissions': [],
#      'ua_from': 'Київ--Одеса',
#      'ua_to': 'Будапешт'},
#     {'airline_limits': [],
#      'comment': '',
#      'en_from': 'other',
#      'en_to': 'other',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'інші',
#      'ua_to': 'інші'}],
#    'date': '09.11.1995',
#    'stage': 'чинна',
#    'uacountry': 'Угорщина',
#    'url': 'http://zakon3.rada.gov.ua/laws/show/en/348_024'}},
#  {'encoutry': 'Iceland',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Kiev',
#      'en_to': 'Reykjavik',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Київ',
#      'ua_to': 'Рейк’явік'}],
#    'date': '',
#    'stage': 'проект',
#    'uacountry': 'Ісландія',
#    'url': ''}},
#  {'encoutry': 'India',
#   'treaty': {'conditions': [{'airline_limits': [{'limit': 2,
#        'scope': 'condition'}],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Delhi',
#      'flight_limits': [{'limit': 14, 'scope': 'condition'},
#       {'limit': 7, 'scope': 'airline'}],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Делі'},
#     {'airline_limits': [{'limit': 2, 'scope': 'condition'}],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'New Delhi--Goa--Amritsar',
#      'flight_limits': [{'limit': 2, 'scope': 'point'}],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Нью-Делі--Гоа--Амрітсар'}],
#    'date': '07.07.1995',
#    'stage': 'чинна',
#    'uacountry': 'Індія',
#    'url': 'http://zakon2.rada.gov.ua/laws/show/356_021'}},
#  {'encoutry': 'Indonesia',
#   'treaty': {'conditions': [{'airline_limits': [{'limit': 1,
#        'scope': 'condition'}],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Jakarta',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Джакарта'}],
#    'date': '16.01.1999',
#    'stage': 'чинна',
#    'uacountry': 'Індонезія',
#    'url': ''}},
#  {'encoutry': 'Iran',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Iran',
#      'flight_limits': [{'limit': 4, 'scope': 'point'}],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Іран'}],
#    'date': '17.09.1995',
#    'stage': 'чинна',
#    'uacountry': 'Іран',
#    'url': 'http://zakon2.rada.gov.ua/laws/show/364_001'}},
#  {'encoutry': 'Iraq',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Iraq',
#      'flight_limits': [{'limit': 7, 'scope': 'point'}],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Ірак'}],
#    'date': '',
#    'stage': 'проект',
#    'uacountry': 'Ірак',
#    'url': ''}},
#  {'encoutry': 'Ireland',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Ireland',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Ірландія'}],
#    'date': '',
#    'stage': 'проект',
#    'uacountry': 'Ірландія',
#    'url': ''}},
#  {'encoutry': 'Israel',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Kiev',
#      'en_to': 'Tel-aviv',
#      'flight_limits': [{'limit': 31, 'scope': 'condition'}],
#      'permissions': [{'airline_name': 'ЯнЕір ЛТД',
#        'annul_date': '',
#        'annul_reason': '',
#        'country': 'Держава Ізраїль',
#        'date': '22.11.2013',
#        'encountry': 'Israel',
#        'from_city': 'Київ',
#        'from_encity': 'Kiev',
#        'given_by': 'Протокол засідання комісії МІУ від 22.11.2013 № 9',
#        'given_date': '09.12.2013',
#        'iata_airline': 'YE',
#        'icao_airline': 'ANR',
#        'max_freq': '1',
#        'min_freq': 0,
#        'right_id': 635,
#        'schedules': {'flights': ['YE334', 'YE333'], 'freq': 3},
#        'to_city': 'Тель-Авів',
#        'to_encity': 'Tel-aviv',
#        'type_of_right': 'Регулярні міжнародні',
#        'valid_from': '22.11.2013',
#        'valid_till': '22.11.2023'},
#       {'airline_name': 'МАУ',
#        'annul_date': '',
#        'annul_reason': '',
#        'country': 'Держава Ізраїль',
#        'date': '20.09.2013',
#        'encountry': 'Israel',
#        'from_city': 'Київ',
#        'from_encity': 'Kiev',
#        'given_by': 'Протокол засідання комісії МІУ № 6 від 20.09.2013',
#        'given_date': '23.10.2013',
#        'iata_airline': 'PS',
#        'icao_airline': 'AUI',
#        'max_freq': '23',
#        'min_freq': 0,
#        'right_id': 590,
#        'schedules': {'flights': ['PS782',
#          'PS779',
#          'PS781',
#          'PS772',
#          'PS778',
#          'PS780',
#          'PS775',
#          'PS777',
#          'PS776'],
#         'freq': 17},
#        'to_city': 'Тель-Авів',
#        'to_encity': 'Tel-aviv',
#        'type_of_right': 'Регулярні міжнародні',
#        'valid_from': '20.09.2013',
#        'valid_till': '20.09.2023'}],
#      'ua_from': 'Київ',
#      'ua_to': 'Тель-Авів'},
#     {'airline_limits': [{'limit': 1, 'scope': 'point'}],
#      'comment': '',
#      'en_from': 'other',
#      'en_to': 'other',
#      'flight_limits': [{'limit': 14, 'scope': 'condition'}],
#      'permissions': [],
#      'ua_from': 'інші',
#      'ua_to': 'інші'}],
#    'date': '17.09.1995',
#    'stage': 'чинна',
#    'uacountry': 'Ізраїль',
#    'url': 'http://search.ligazakon.ua/l_doc2.nsf/link1/MU10195.html\nhttp://zakon2.rada.gov.ua/laws/show/376_006'}},
#  {'encoutry': 'Italy',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Italy',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Італія'}],
#    'date': '04.02.1998',
#    'stage': 'чинна',
#    'uacountry': 'Італія',
#    'url': 'http://zakon2.rada.gov.ua/laws/show/380_018'}},
#  {'encoutry': 'Jordan',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Jordan',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Йорданія'}],
#    'date': '11.10.2006',
#    'stage': 'чинна',
#    'uacountry': 'Йорданія',
#    'url': 'http://zakon2.rada.gov.ua/laws/show/400_007'}},
#  {'encoutry': 'Kazakhstan',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Kiev',
#      'en_to': 'Aktau',
#      'flight_limits': [{'limit': 2, 'scope': 'condition'}],
#      'permissions': [{'airline_name': 'МАУ',
#        'annul_date': '',
#        'annul_reason': '',
#        'country': 'Республіка Казахстан',
#        'date': '30.10.2015',
#        'encountry': 'Kazakhstan',
#        'from_city': 'Київ',
#        'from_encity': 'Kiev',
#        'given_by': 'Протокол засідання комісії ДАС №6 від 30.10.2015',
#        'given_date': '30.10.2015',
#        'iata_airline': 'PS',
#        'icao_airline': 'AUI',
#        'max_freq': '2',
#        'min_freq': 0,
#        'right_id': 1238,
#        'to_city': 'Актау',
#        'to_encity': 'Aktau',
#        'type_of_right': 'Регулярні міжнародні',
#        'valid_from': '30.10.2015',
#        'valid_till': '20.10.2065'}],
#      'ua_from': 'Київ',
#      'ua_to': 'Актау'},
#     {'airline_limits': [],
#      'comment': '',
#      'en_from': 'other',
#      'en_to': 'Almaty--Astana--Karaganda--Kostanay--Ust Kamenogorsk--Pavlodar',
#      'flight_limits': [{'limit': 14, 'scope': 'condition'}],
#      'permissions': [],
#      'ua_from': 'інші',
#      'ua_to': 'Алмати--Астана--Караганда--Костанай--Усть-Каменогорск--Павлодар'}],
#    'date': '22.02.1993',
#    'stage': 'чинна',
#    'uacountry': 'Казахстан',
#    'url': 'http://zakon2.rada.gov.ua/laws/show/398_018'}},
#  {'encoutry': 'Kuwait',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Kiev',
#      'en_to': 'Kuwait City',
#      'flight_limits': [{'limit': 4, 'scope': 'condition'}],
#      'permissions': [],
#      'ua_from': 'Київ',
#      'ua_to': 'Кувейт'}],
#    'date': '05.08.2009',
#    'stage': 'чинна',
#    'uacountry': 'Кувейт',
#    'url': 'http://zakon2.rada.gov.ua/laws/show/en/414_009'}},
#  {'encoutry': 'Kyrgyzstan',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': 'Відповідно до п.4 ст. 3 Угоди усі комерційні питання, в т.ч. частоти вирішуються між призначеними а/к і надаються на затвердження авіаційним властям',
#      'en_from': 'Ukraine',
#      'en_to': 'Kyrgyzstan',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Киргизстан'}],
#    'date': '23.02.1993',
#    'stage': 'чинна',
#    'uacountry': 'Киргизстан',
#    'url': 'http://zakon2.rada.gov.ua/laws/show/417_035'}},
#  {'encoutry': 'Latvia',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Riga',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Рига'}],
#    'date': '31.01.1996',
#    'stage': 'чинна',
#    'uacountry': 'Латвія',
#    'url': 'http://zakon2.rada.gov.ua/laws/show/428_015'}},
#  {'encoutry': 'Lebanon',
#   'treaty': {'conditions': [{'airline_limits': [{'limit': 1,
#        'scope': 'point'}],
#      'comment': 'Додатково 2 р/т для суто вантажних перевезень',
#      'en_from': 'Kiev--Simferopol--Donetsk',
#      'en_to': 'Beirut',
#      'flight_limits': [{'limit': 2, 'scope': 'condition'}],
#      'permissions': [],
#      'ua_from': 'Київ--Сімферополь--Донецьк',
#      'ua_to': 'Бейрут'}],
#    'date': '19.08.2003',
#    'stage': 'чинна',
#    'uacountry': 'Ліван',
#    'url': 'http://zakon2.rada.gov.ua/laws/show/422_002'}},
#  {'encoutry': 'Libya',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Kiev',
#      'en_to': 'Tripoli',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Київ',
#      'ua_to': 'Триполі'}],
#    'date': '04.11.2002',
#    'stage': 'чинна',
#    'uacountry': 'Лівія',
#    'url': ''}},
#  {'encoutry': 'Lithuania',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Kiev--Simferopol--Odessa',
#      'en_to': 'Vilnius--Kaunas--Palanga',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Київ--Сімферополь--Одеса',
#      'ua_to': 'Вільнюс--Каунас--Паланга'}],
#    'date': '28.12.1993',
#    'stage': 'чинна',
#    'uacountry': 'Литва',
#    'url': 'http://zakon3.rada.gov.ua/laws/show/440_608'}},
#  {'encoutry': 'Luxembourg',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Luxembourg',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Люксембург'}],
#    'date': '15.11.1995',
#    'stage': 'чинна',
#    'uacountry': 'Люксембург',
#    'url': 'http://zakon2.rada.gov.ua/laws/show/442_004'}},
#  {'encoutry': 'Macedonia',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Skopje--Ohrid',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Скоп’є--Охрід'}],
#    'date': '29.04.1999',
#    'stage': 'чинна',
#    'uacountry': 'Македонія',
#    'url': ''}},
#  {'encoutry': 'Malaysia',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Kiev',
#      'en_to': 'Kuala Lumpur',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Київ',
#      'ua_to': 'Куала-Лумпур'}],
#    'date': '',
#    'stage': 'проект',
#    'uacountry': 'Малайзія',
#    'url': ''}},
#  {'encoutry': 'Maldives',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Maldives',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Мальдіви'}],
#    'date': '',
#    'stage': 'парафована',
#    'uacountry': 'Мальдіви',
#    'url': ''}},
#  {'encoutry': 'Malta',
#   'treaty': {'conditions': [{'airline_limits': [{'limit': 1,
#        'scope': 'condition'}],
#      'comment': '',
#      'en_from': 'Kiev',
#      'en_to': 'Lucca',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Київ',
#      'ua_to': 'Лука'}],
#    'date': '',
#    'stage': 'парафована',
#    'uacountry': 'Мальта',
#    'url': ''}},
#  {'encoutry': 'Moldova',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': 'Інші рейси узгоджуються між авіакомпаніями',
#      'en_from': 'Kiev',
#      'en_to': 'Chisinau',
#      'flight_limits': [{'limit': 7, 'scope': 'condition'}],
#      'permissions': [{'airline_name': 'МАУ',
#        'annul_date': '',
#        'annul_reason': '',
#        'country': 'Республіка Молдова',
#        'date': '22.11.2013',
#        'encountry': 'Moldova',
#        'from_city': 'Київ',
#        'from_encity': 'Kiev',
#        'given_by': 'Протокол засідання комісії МІУ № 9 від 22.11.2013',
#        'given_date': '09.12.2013',
#        'iata_airline': 'PS',
#        'icao_airline': 'AUI',
#        'max_freq': '7',
#        'min_freq': 0,
#        'right_id': 645,
#        'schedules': {'flights': ['PS898', 'PS897'], 'freq': 7},
#        'to_city': 'Кишинеу',
#        'to_encity': 'Chisinau',
#        'type_of_right': 'Регулярні міжнародні',
#        'valid_from': '22.11.2013',
#        'valid_till': ''}],
#      'ua_from': 'Київ',
#      'ua_to': 'Кишинів'}],
#    'date': '20.03.1993',
#    'stage': 'чинна',
#    'uacountry': 'Молдова',
#    'url': 'http://zakon2.rada.gov.ua/laws/show/ru/498_085'}},
#  {'encoutry': 'Mongolia',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Kiev',
#      'en_to': 'Ulaanbaatar',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Київ',
#      'ua_to': 'Улан-Батор'}],
#    'date': '22.07.1993',
#    'stage': 'чинна',
#    'uacountry': 'Монголія',
#    'url': 'http://zakon2.rada.gov.ua/laws/show/496_016'}},
#  {'encoutry': 'Montenegro',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Kiev',
#      'en_to': 'Podgorica',
#      'flight_limits': [{'limit': 7, 'scope': 'condition'}],
#      'permissions': [],
#      'ua_from': 'Київ',
#      'ua_to': 'Подгориця'}],
#    'date': '07.12.2011',
#    'stage': 'чинна',
#    'uacountry': 'Чорногорія',
#    'url': 'http://zakon2.rada.gov.ua/laws/show/892_012'}},
#  {'encoutry': 'Morocco',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Casablanca--NA',
#      'flight_limits': [{'limit': 2, 'scope': 'condition'}],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Касабланка--NA'}],
#    'date': '',
#    'stage': 'парафована',
#    'uacountry': 'Марокко',
#    'url': ''}},
#  {'encoutry': 'Netherlands',
#   'treaty': {'conditions': [{'airline_limits': [{'limit': 1,
#        'scope': 'condition'}],
#      'comment': '',
#      'en_from': 'Kiev',
#      'en_to': 'Amsterdam',
#      'flight_limits': [{'limit': 14, 'scope': 'condition'}],
#      'permissions': [{'airline_name': 'МАУ',
#        'annul_date': '',
#        'annul_reason': '',
#        'country': 'Королівство Нідерланди',
#        'date': '12.12.2016',
#        'encountry': 'Netherlands',
#        'from_city': 'Київ',
#        'from_encity': 'Kiev',
#        'given_by': 'Протокол засідання комісії ДАС № 19 від 30.11.2016',
#        'given_date': '12.12.2016',
#        'iata_airline': 'PS',
#        'icao_airline': 'AUI',
#        'max_freq': '14',
#        'min_freq': 0,
#        'right_id': 571,
#        'schedules': {'flights': ['PS9384',
#          'PS105',
#          'PS106',
#          'PS9386',
#          'PS102',
#          'PS101',
#          'PS9385',
#          'PS9383'],
#         'freq': 7},
#        'to_city': 'Амстердам',
#        'to_encity': 'Amsterdam',
#        'type_of_right': 'Регулярні міжнародні',
#        'valid_from': '20.09.2013',
#        'valid_till': '20.09.2023'}],
#      'ua_from': 'Київ',
#      'ua_to': 'Амстердам'},
#     {'airline_limits': [{'limit': 1, 'scope': 'condition'}],
#      'comment': '',
#      'en_from': 'other',
#      'en_to': 'other',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'інші',
#      'ua_to': 'інші'}],
#    'date': '03.06.1994',
#    'stage': 'чинна',
#    'uacountry': 'Нідерланди',
#    'url': 'http://zakon3.rada.gov.ua/laws/show/528_007'}},
#  {'encoutry': 'Norway',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Kiev--NA--NA',
#      'en_to': 'Oslo--Sandefjord--NA',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Київ--NA--NA',
#      'ua_to': 'Осло--Сандефьорд--NA'}],
#    'date': '27.03.2001',
#    'stage': 'чинна',
#    'uacountry': 'Норвегія',
#    'url': ''}},
#  {'encoutry': 'Pakistan',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '1 рейс на маршруті для широкофюзеляжних літаків, 2 р/т на маршруті для вузькофюзеляжних',
#      'en_from': 'Ukraine',
#      'en_to': 'Karachi--Islamabad--Peshawar--Lahore',
#      'flight_limits': [{'limit': 8, 'scope': 'condition'},
#       {'limit': 2, 'scope': 'point'}],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Карачі--Ісламабад--Пешовар--Лахор'}],
#    'date': '',
#    'stage': 'проект',
#    'uacountry': 'Пакистан',
#    'url': ''}},
#  {'encoutry': 'Poland',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Poland',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Польша'}],
#    'date': '28.07.2016',
#    'stage': 'чинна',
#    'uacountry': 'Польша',
#    'url': 'http://zakon3.rada.gov.ua/laws/show/616_024'}},
#  {'encoutry': 'Portugal',
#   'treaty': {'conditions': [{'airline_limits': [{'limit': 2,
#        'scope': 'condition'}],
#      'comment': '',
#      'en_from': 'Kiev',
#      'en_to': 'Lisbon',
#      'flight_limits': [],
#      'permissions': [{'airline_name': 'МАУ',
#        'annul_date': '',
#        'annul_reason': '',
#        'country': 'Португальська Республіка',
#        'date': '31.01.2014',
#        'encountry': 'Portugal',
#        'from_city': 'Київ',
#        'from_encity': 'Kiev',
#        'given_by': 'Протокол засідання комісії МІУ № 11 від 31.01.2014',
#        'given_date': '20.02.2014',
#        'iata_airline': 'PS',
#        'icao_airline': 'AUI',
#        'max_freq': '4',
#        'min_freq': 0,
#        'right_id': 582,
#        'to_city': 'Лісабон',
#        'to_encity': 'Lisbon',
#        'type_of_right': 'Регулярні міжнародні',
#        'valid_from': '20.09.2013',
#        'valid_till': '20.09.2023'}],
#      'ua_from': 'Київ',
#      'ua_to': 'Лісабон'}],
#    'date': '16.03.2012',
#    'stage': 'чинна',
#    'uacountry': 'Португалія',
#    'url': ''}},
#  {'encoutry': 'Qatar',
#   'treaty': {'conditions': [{'airline_limits': [{'limit': 1,
#        'scope': 'condition'}],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Qatar',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Катар'}],
#    'date': '16.11.2012',
#    'stage': 'чинна',
#    'uacountry': 'Катар',
#    'url': 'http://zakon3.rada.gov.ua/laws/show/634_005'}},
#  {'encoutry': 'Romania',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Romania',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Румунія'}],
#    'date': '01.06.1999',
#    'stage': 'чинна',
#    'uacountry': 'Румунія',
#    'url': 'http://zakon3.rada.gov.ua/laws/show/ru/642_044'}},
#  {'encoutry': 'Russia',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Russia',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Російська Федерація'}],
#    'date': '02.03.1995',
#    'stage': 'чинна',
#    'uacountry': 'Російська Федерація',
#    'url': 'http://zakon3.rada.gov.ua/laws/show/643_140'}},
#  {'encoutry': 'Saudi Arabia',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Dammam',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Даммам'},
#     {'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'other',
#      'flight_limits': [{'limit': 7, 'scope': 'point'}],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'інші'}],
#    'date': '',
#    'stage': 'проект',
#    'uacountry': 'Саудівська Аравія',
#    'url': ''}},
#  {'encoutry': 'Serbia',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Serbia',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Сербія'}],
#    'date': '25.01.1996',
#    'stage': 'парафована',
#    'uacountry': 'Сербія',
#    'url': ''}},
#  {'encoutry': 'Singapore',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Singapore',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Сінгапур'}],
#    'date': '',
#    'stage': 'проект',
#    'uacountry': 'Сінгапур',
#    'url': ''}},
#  {'encoutry': 'Slovakia',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Slovakia',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Словаччина'}],
#    'date': '28.01.1995',
#    'stage': 'чинна',
#    'uacountry': 'Словаччина',
#    'url': 'http://zakon3.rada.gov.ua/laws/show/703_051'}},
#  {'encoutry': 'Slovenia',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Kiev',
#      'en_to': 'Ljubljana',
#      'flight_limits': [],
#      'permissions': [{'airline_name': 'Дніпроавіа',
#        'annul_date': '',
#        'annul_reason': '',
#        'country': 'Республіка Словенія',
#        'date': '12.12.2016',
#        'encountry': 'Slovenia',
#        'from_city': 'Київ',
#        'from_encity': 'Kiev',
#        'given_by': 'Протокол засідання комісії ДАС № 19 від 30.11.2016',
#        'given_date': '12.12.2016',
#        'iata_airline': 'Z6',
#        'icao_airline': 'UDN',
#        'max_freq': '7',
#        'min_freq': 0,
#        'right_id': 1678,
#        'to_city': 'Любляна',
#        'to_encity': 'Ljubljana',
#        'type_of_right': 'Регулярні міжнародні',
#        'valid_from': '12.12.2016',
#        'valid_till': '30.11.2026'}],
#      'ua_from': 'Київ',
#      'ua_to': 'Любляна'}],
#    'date': '14.06.2001',
#    'stage': 'чинна',
#    'uacountry': 'Словенія',
#    'url': ''}},
#  {'encoutry': 'South Africa',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'South Africa',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'ПАР'}],
#    'date': '',
#    'stage': 'проект',
#    'uacountry': 'ПАР',
#    'url': ''}},
#  {'encoutry': 'South Korea',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'South Korea',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Республіка Корея'}],
#    'date': '06.03.2003',
#    'stage': 'чинна',
#    'uacountry': 'Республіка Корея',
#    'url': 'http://zakon3.rada.gov.ua/laws/show/410_005'}},
#  {'encoutry': 'Spain',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Spain',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Іспанія'}],
#    'date': '27.03.1998',
#    'stage': 'чинна',
#    'uacountry': 'Іспанія',
#    'url': 'http://zakon2.rada.gov.ua/laws/show/724_019'}},
#  {'encoutry': 'Sri Lanka',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Kiev--Odessa',
#      'en_to': 'Colombo',
#      'flight_limits': [{'limit': 7, 'scope': 'condition'}],
#      'permissions': [],
#      'ua_from': 'Київ--Одеса',
#      'ua_to': 'Коломбо'}],
#    'date': '18.06.2012',
#    'stage': 'чинна',
#    'uacountry': 'Шрі-Ланка',
#    'url': 'http://zakon3.rada.gov.ua/laws/show/144_006'}},
#  {'encoutry': 'Sweden',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Stockholm--NA--NA',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Стокгольм--NA--NA'}],
#    'date': '27.03.2001',
#    'stage': 'чинна',
#    'uacountry': 'Швеція',
#    'url': 'http://zakon3.rada.gov.ua/laws/show/752_022'}},
#  {'encoutry': 'Switzerland',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Switzerland',
#      'flight_limits': [{'limit': 19, 'scope': 'condition'}],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Швейцарія'}],
#    'date': '25.03.1997',
#    'stage': 'чинна',
#    'uacountry': 'Швейцарія',
#    'url': 'http://zakon2.rada.gov.ua/laws/show/756_032'}},
#  {'encoutry': 'Syria',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Damascus--Aleppo',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Дамаск--Алеппо'}],
#    'date': '02.02.1999',
#    'stage': 'чинна',
#    'uacountry': 'Сирія',
#    'url': ''}},
#  {'encoutry': 'Tajikistan',
#   'treaty': {'conditions': [{'airline_limits': [{'limit': 1,
#        'scope': 'condition'}],
#      'comment': '',
#      'en_from': 'Kiev--Lviv',
#      'en_to': 'Dushanbe',
#      'flight_limits': [{'limit': 4, 'scope': 'condition'},
#       {'limit': 2, 'scope': 'point'}],
#      'permissions': [],
#      'ua_from': 'Київ--Львів',
#      'ua_to': 'Душанбе'}],
#    'date': '07.12.2009',
#    'stage': 'чинна',
#    'uacountry': 'Таджикістан',
#    'url': 'http://zakon3.rada.gov.ua/laws/show/762_039'}},
#  {'encoutry': 'Thailand',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Thailand',
#      'flight_limits': [{'limit': 21, 'scope': 'condition'}],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Таїланд'}],
#    'date': '17.04.2007',
#    'stage': 'чинна',
#    'uacountry': 'Таїланд',
#    'url': 'http://zakon2.rada.gov.ua/laws/show/764_004'}},
#  {'encoutry': 'Tunisia',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Tunisia',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Туніс'}],
#    'date': '25.08.1994',
#    'stage': 'чинна',
#    'uacountry': 'Туніс',
#    'url': 'http://zakon3.rada.gov.ua/laws/show/788_011'}},
#  {'encoutry': 'Turkey',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Kiev',
#      'en_to': 'Istanbul',
#      'flight_limits': [{'limit': 16, 'scope': 'condition'}],
#      'permissions': [{'airline_name': 'МАУ',
#        'annul_date': '',
#        'annul_reason': '',
#        'country': 'Республіка Туреччина',
#        'date': '31.01.2014',
#        'encountry': 'Turkey',
#        'from_city': 'Київ',
#        'from_encity': 'Kiev',
#        'given_by': 'Протокол засідання комісії МІУ № 11 від 31.01.2014',
#        'given_date': '20.02.2014',
#        'iata_airline': 'PS',
#        'icao_airline': 'AUI',
#        'max_freq': '16',
#        'min_freq': 0,
#        'right_id': 594,
#        'schedules': {'flights': ['PS9571',
#          'PS711',
#          'PS712',
#          'PS9557',
#          'PS9558',
#          'PS715',
#          'PS713',
#          'PS714',
#          'PS716',
#          'PS9572'],
#         'freq': 16},
#        'to_city': 'Стамбул',
#        'to_encity': 'Istanbul',
#        'type_of_right': 'Регулярні міжнародні',
#        'valid_from': '20.09.2013',
#        'valid_till': ''}],
#      'ua_from': 'Київ',
#      'ua_to': 'Стамбул'},
#     {'airline_limits': [],
#      'comment': '',
#      'en_from': 'Odessa',
#      'en_to': 'Istanbul',
#      'flight_limits': [{'limit': 14, 'scope': 'condition'}],
#      'permissions': [{'airline_name': 'МАУ',
#        'annul_date': '',
#        'annul_reason': '',
#        'country': 'Республіка Туреччина',
#        'date': '02.07.2015',
#        'encountry': 'Turkey',
#        'from_city': 'Одеса',
#        'from_encity': 'Odessa',
#        'given_by': 'Протокол засідання комісії ДАСУ №2 від 01.07.2015',
#        'given_date': '03.07.2015',
#        'iata_airline': 'PS',
#        'icao_airline': 'AUI',
#        'max_freq': '14',
#        'min_freq': 0,
#        'right_id': 595,
#        'schedules': {'flights': ['PS717',
#          'PS720',
#          'PS719',
#          'PS718',
#          'PS9565',
#          'PS9566',
#          'PS9567',
#          'PS9568'],
#         'freq': 18},
#        'to_city': 'Стамбул',
#        'to_encity': 'Istanbul',
#        'type_of_right': 'Регулярні міжнародні',
#        'valid_from': '20.09.2013',
#        'valid_till': ''}],
#      'ua_from': 'Одеса',
#      'ua_to': 'Стамбул'},
#     {'airline_limits': [],
#      'comment': '',
#      'en_from': 'Lviv',
#      'en_to': 'Istanbul',
#      'flight_limits': [{'limit': 15, 'scope': 'condition'}],
#      'permissions': [{'airline_name': 'МАУ',
#        'annul_date': '',
#        'annul_reason': '',
#        'country': 'Республіка Туреччина',
#        'date': '04.11.2016',
#        'encountry': 'Turkey',
#        'from_city': 'Львів',
#        'from_encity': 'Lviv',
#        'given_by': 'Протокол засідання комісії ДАС № 18 від 28.10.2016',
#        'given_date': '04.11.2016',
#        'iata_airline': 'PS',
#        'icao_airline': 'AUI',
#        'max_freq': '7',
#        'min_freq': 0,
#        'right_id': 1082,
#        'to_city': 'Стамбул',
#        'to_encity': 'Istanbul',
#        'type_of_right': 'Регулярні міжнародні',
#        'valid_from': '02.07.2015',
#        'valid_till': ''},
#       {'airline_name': 'АТЛАСДЖЕТ УКРАЇНА',
#        'annul_date': '',
#        'annul_reason': '',
#        'country': 'Республіка Туреччина',
#        'date': '12.04.2017',
#        'encountry': 'Turkey',
#        'from_city': 'Львів',
#        'from_encity': 'Lviv',
#        'given_by': 'Протокол засідання комісії ДАС № 23 від 28.03.2017',
#        'given_date': '13.04.2017',
#        'iata_airline': 'UH',
#        'icao_airline': 'UJX',
#        'max_freq': '7',
#        'min_freq': 0,
#        'right_id': 1078,
#        'schedules': {'flights': ['UH270', 'UH271'], 'freq': 3},
#        'to_city': 'Стамбул',
#        'to_encity': 'Istanbul',
#        'type_of_right': 'Регулярні міжнародні',
#        'valid_from': '02.07.2015',
#        'valid_till': '01.11.2025'}],
#      'ua_from': 'Львів',
#      'ua_to': 'Стамбул'},
#     {'airline_limits': [],
#      'comment': '',
#      'en_from': 'Kherson',
#      'en_to': 'Istanbul',
#      'flight_limits': [{'limit': 10, 'scope': 'condition'}],
#      'permissions': [{'airline_name': 'МАУ',
#        'annul_date': '',
#        'annul_reason': '',
#        'country': 'Республіка Туреччина',
#        'date': '04.11.2016',
#        'encountry': 'Turkey',
#        'from_city': 'Херсон',
#        'from_encity': 'Kherson',
#        'given_by': 'Протокол засідання комісії ДАС № 18 від 28.10.2016',
#        'given_date': '04.11.2016',
#        'iata_airline': 'PS',
#        'icao_airline': 'AUI',
#        'max_freq': '7',
#        'min_freq': 0,
#        'right_id': 1667,
#        'to_city': 'Стамбул',
#        'to_encity': 'Istanbul',
#        'type_of_right': 'Регулярні міжнародні',
#        'valid_from': '04.11.2016',
#        'valid_till': '01.11.2066'}],
#      'ua_from': 'Херсон',
#      'ua_to': 'Стамбул'},
#     {'airline_limits': [],
#      'comment': '',
#      'en_from': 'Zaporizhia',
#      'en_to': 'Istanbul',
#      'flight_limits': [{'limit': 14, 'scope': 'condition'}],
#      'permissions': [{'airline_name': 'МАУ',
#        'annul_date': '',
#        'annul_reason': '',
#        'country': 'Республіка Туреччина',
#        'date': '04.11.2016',
#        'encountry': 'Turkey',
#        'from_city': 'Запоріжжя',
#        'from_encity': 'Zaporizhia',
#        'given_by': 'Протокол засідання комісії ДАС № 18 від 28.10.2016',
#        'given_date': '04.11.2016',
#        'iata_airline': 'PS',
#        'icao_airline': 'AUI',
#        'max_freq': '4',
#        'min_freq': 0,
#        'right_id': 1669,
#        'to_city': 'Стамбул',
#        'to_encity': 'Istanbul',
#        'type_of_right': 'Регулярні міжнародні',
#        'valid_from': '04.11.2016',
#        'valid_till': '01.11.2066'},
#       {'airline_name': 'АТЛАСДЖЕТ УКРАЇНА',
#        'annul_date': '',
#        'annul_reason': '',
#        'country': 'Республіка Туреччина',
#        'date': '12.04.2017',
#        'encountry': 'Turkey',
#        'from_city': 'Запоріжжя',
#        'from_encity': 'Zaporizhia',
#        'given_by': 'Протокол засідання комісії ДАС № 23 від 28.03.2017',
#        'given_date': '13.04.2017',
#        'iata_airline': 'UH',
#        'icao_airline': 'UJX',
#        'max_freq': '10',
#        'min_freq': 0,
#        'right_id': 1024,
#        'schedules': {'flights': ['UH261', 'UH260'], 'freq': 3},
#        'to_city': 'Стамбул',
#        'to_encity': 'Istanbul',
#        'type_of_right': 'Регулярні міжнародні',
#        'valid_from': '10.06.2015',
#        'valid_till': '01.11.2025'}],
#      'ua_from': 'Запоріжжя',
#      'ua_to': 'Стамбул'},
#     {'airline_limits': [],
#      'comment': '',
#      'en_from': 'Kharkiv',
#      'en_to': 'Istanbul',
#      'flight_limits': [{'limit': 14, 'scope': 'condition'}],
#      'permissions': [{'airline_name': 'АТЛАСДЖЕТ УКРАЇНА',
#        'annul_date': '',
#        'annul_reason': '',
#        'country': 'Республіка Туреччина',
#        'date': '12.04.2017',
#        'encountry': 'Turkey',
#        'from_city': 'Харків',
#        'from_encity': 'Kharkiv',
#        'given_by': 'Протокол засідання комісії ДАС № 23 від 28.03.2017',
#        'given_date': '13.04.2017',
#        'iata_airline': 'UH',
#        'icao_airline': 'UJX',
#        'max_freq': '14',
#        'min_freq': 0,
#        'right_id': 1079,
#        'schedules': {'flights': ['UH250', 'UH251'], 'freq': 10},
#        'to_city': 'Стамбул',
#        'to_encity': 'Istanbul',
#        'type_of_right': 'Регулярні міжнародні',
#        'valid_from': '02.07.2015',
#        'valid_till': '01.11.2025'}],
#      'ua_from': 'Харків',
#      'ua_to': 'Стамбул'},
#     {'airline_limits': [],
#      'comment': '',
#      'en_from': 'Vinnytsia',
#      'en_to': 'Istanbul',
#      'flight_limits': [{'limit': 10, 'scope': 'condition'}],
#      'permissions': [{'airline_name': 'МАУ',
#        'annul_date': '',
#        'annul_reason': '',
#        'country': 'Республіка Туреччина',
#        'date': '02.07.2015',
#        'encountry': 'Turkey',
#        'from_city': 'Вінниця',
#        'from_encity': 'Vinnytsia',
#        'given_by': 'Протокол засідання комісії ДАСУ №2 від 01.07.2015',
#        'given_date': '03.07.2015',
#        'iata_airline': 'PS',
#        'icao_airline': 'AUI',
#        'max_freq': '3',
#        'min_freq': 0,
#        'right_id': 1081,
#        'to_city': 'Стамбул',
#        'to_encity': 'Istanbul',
#        'type_of_right': 'Регулярні міжнародні',
#        'valid_from': '02.07.2015',
#        'valid_till': ''}],
#      'ua_from': 'Вінниця',
#      'ua_to': 'Стамбул'},
#     {'airline_limits': [],
#      'comment': '',
#      'en_from': 'Donetsk--Simferopol',
#      'en_to': 'Istanbul',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Донецьк--Сімферополь',
#      'ua_to': 'Стамбул'},
#     {'airline_limits': [],
#      'comment': '',
#      'en_from': 'Kiev',
#      'en_to': 'Ankara',
#      'flight_limits': [],
#      'permissions': [{'airline_name': 'МАУ',
#        'annul_date': '',
#        'annul_reason': '',
#        'country': 'Республіка Туреччина',
#        'date': '09.12.2015',
#        'encountry': 'Turkey',
#        'from_city': 'Київ',
#        'from_encity': 'Kiev',
#        'given_by': 'Протокол засідання комісії ДАС №7 від 09.12.2015',
#        'given_date': '11.12.2015',
#        'iata_airline': 'PS',
#        'icao_airline': 'AUI',
#        'max_freq': '7',
#        'min_freq': 0,
#        'right_id': 1245,
#        'schedules': {'flights': ['PS722', 'PS721'], 'freq': 14},
#        'to_city': 'Анкара',
#        'to_encity': 'Ankara',
#        'type_of_right': 'Регулярні міжнародні',
#        'valid_from': '09.12.2015',
#        'valid_till': '01.12.2065'}],
#      'ua_from': 'Київ',
#      'ua_to': 'Анкара'},
#     {'airline_limits': [],
#      'comment': '',
#      'en_from': 'other',
#      'en_to': 'other',
#      'flight_limits': [{'limit': 7, 'scope': 'condition'}],
#      'permissions': [],
#      'ua_from': 'інші',
#      'ua_to': 'інші'}],
#    'date': '31.10.2013',
#    'stage': 'чинна',
#    'uacountry': 'Туреччина',
#    'url': 'http://zakon3.rada.gov.ua/laws/show/792_083'}},
#  {'encoutry': 'Turkmenistan',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Turkmenistan',
#      'flight_limits': [{'limit': 3, 'scope': 'point'}],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'Туркменістан'}],
#    'date': '25.02.1993',
#    'stage': 'чинна',
#    'uacountry': 'Туркменістан',
#    'url': ''}},
#  {'encoutry': 'United Arab Emirates',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'United Arab Emirates',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'ОАЕ'}],
#    'date': '26.11.2012',
#    'stage': 'підписана',
#    'uacountry': 'ОАЕ',
#    'url': 'http://zakon3.rada.gov.ua/laws/show/784_012'}},
#  {'encoutry': 'United Kingdom',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Kiev',
#      'en_to': 'London',
#      'flight_limits': [{'limit': 17, 'scope': 'condition'}],
#      'permissions': [{'airline_name': 'Браво',
#        'annul_date': '',
#        'annul_reason': '',
#        'country': 'Королівство Великої Британії та Північної Ірландії',
#        'date': '28.08.2015',
#        'encountry': 'United Kingdom',
#        'from_city': 'Київ',
#        'from_encity': 'Kiev',
#        'given_by': 'Протокол засідання комісії ДАС №4',
#        'given_date': '28.08.2015',
#        'iata_airline': '',
#        'icao_airline': 'BAY',
#        'max_freq': '3',
#        'min_freq': 0,
#        'right_id': 1180,
#        'schedules': {'flights': ['PS114', 'PS113', 'PS111', 'PS112'],
#         'freq': 7},
#        'to_city': 'Лондон',
#        'to_encity': 'London',
#        'type_of_right': 'Регулярні міжнародні',
#        'valid_from': '01.09.2015',
#        'valid_till': '31.12.2025'},
#       {'airline_name': 'МАУ',
#        'annul_date': '',
#        'annul_reason': '',
#        'country': 'Королівство Великої Британії та Північної Ірландії',
#        'date': '20.09.2013',
#        'encountry': 'United Kingdom',
#        'from_city': 'Київ',
#        'from_encity': 'Kiev',
#        'given_by': 'Протокол засідання комісії МІУ № 6 від 20.09.2013',
#        'given_date': '23.10.2013',
#        'iata_airline': 'PS',
#        'icao_airline': 'AUI',
#        'max_freq': '14',
#        'min_freq': 0,
#        'right_id': 570,
#        'schedules': {'flights': ['PS114', 'PS113', 'PS111', 'PS112'],
#         'freq': 7},
#        'to_city': 'Лондон',
#        'to_encity': 'London',
#        'type_of_right': 'Регулярні міжнародні',
#        'valid_from': '20.09.2013',
#        'valid_till': ''}],
#      'ua_from': 'Київ',
#      'ua_to': 'Лондон'},
#     {'airline_limits': [],
#      'comment': '',
#      'en_from': 'Kiev',
#      'en_to': 'other',
#      'flight_limits': [{'limit': 7, 'scope': 'condition'}],
#      'permissions': [],
#      'ua_from': 'Київ',
#      'ua_to': 'інші'},
#     {'airline_limits': [],
#      'comment': '',
#      'en_from': 'other',
#      'en_to': 'London',
#      'flight_limits': [{'limit': 7, 'scope': 'condition'}],
#      'permissions': [],
#      'ua_from': 'інші',
#      'ua_to': 'Лондон'},
#     {'airline_limits': [],
#      'comment': '',
#      'en_from': 'other',
#      'en_to': 'other',
#      'flight_limits': [{'limit': 7, 'scope': 'condition'}],
#      'permissions': [],
#      'ua_from': 'інші',
#      'ua_to': 'інші'}],
#    'date': '17.07.2015',
#    'stage': 'чинна',
#    'uacountry': 'Велика Британія',
#    'url': 'http://zakon2.rada.gov.ua/laws/show/826_037'}},
#  {'encoutry': 'United States',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'United States',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'США'}],
#    'date': '14.07.2015',
#    'stage': 'підписана',
#    'uacountry': 'США',
#    'url': 'http://zakon2.rada.gov.ua/laws/show/840_170'}},
#  {'encoutry': 'Uzbekistan',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': 'Частота рейсів встановлюється за домовленістю між а/к',
#      'en_from': 'Kiev',
#      'en_to': 'Tashkent',
#      'flight_limits': [],
#      'permissions': [{'airline_name': 'РОЗА ВІТРІВ',
#        'annul_date': '',
#        'annul_reason': '',
#        'country': 'Республіка Узбекистан',
#        'date': '30.10.2015',
#        'encountry': 'Uzbekistan',
#        'from_city': 'Київ',
#        'from_encity': 'Kiev',
#        'given_by': 'Протокол засідання комісії ДАС №6 від 30.10.2015',
#        'given_date': '30.10.2015',
#        'iata_airline': '7W',
#        'icao_airline': 'WRC',
#        'max_freq': '2',
#        'min_freq': 0,
#        'right_id': 1235,
#        'to_city': 'Ташкент',
#        'to_encity': 'Tashkent',
#        'type_of_right': 'Регулярні міжнародні',
#        'valid_from': '30.10.2015',
#        'valid_till': ''},
#       {'airline_name': 'МАУ',
#        'annul_date': '',
#        'annul_reason': '',
#        'country': 'Республіка Узбекистан',
#        'date': '22.11.2013',
#        'encountry': 'Uzbekistan',
#        'from_city': 'Київ',
#        'from_encity': 'Kiev',
#        'given_by': 'Протокол засідання комісії МІУ № 9 від 22.11.2013',
#        'given_date': '09.12.2013',
#        'iata_airline': 'PS',
#        'icao_airline': 'AUI',
#        'max_freq': '2',
#        'min_freq': 0,
#        'right_id': 639,
#        'to_city': 'Ташкент',
#        'to_encity': 'Tashkent',
#        'type_of_right': 'Регулярні міжнародні',
#        'valid_from': '22.11.2013',
#        'valid_till': ''}],
#      'ua_from': 'Київ',
#      'ua_to': 'Ташкент'},
#     {'airline_limits': [],
#      'comment': '',
#      'en_from': 'Odessa',
#      'en_to': 'Tashkent',
#      'flight_limits': [{'limit': 2, 'scope': 'condition'}],
#      'permissions': [],
#      'ua_from': 'Одеса',
#      'ua_to': 'Ташкент'},
#     {'airline_limits': [],
#      'comment': '',
#      'en_from': 'Simferopol',
#      'en_to': 'Tashkent',
#      'flight_limits': [{'limit': 3, 'scope': 'condition'}],
#      'permissions': [],
#      'ua_from': 'Сімферополь',
#      'ua_to': 'Ташкент'}],
#    'date': '20.02.1993',
#    'stage': 'чинна',
#    'uacountry': 'Узбекістан',
#    'url': 'http://zakon3.rada.gov.ua/laws/show/860_043'}},
#  {'encoutry': 'Vietnam',
#   'treaty': {'conditions': [{'airline_limits': [],
#      'comment': '',
#      'en_from': 'Ukraine',
#      'en_to': 'Vietnam',
#      'flight_limits': [],
#      'permissions': [],
#      'ua_from': 'Україна',
#      'ua_to': 'В’єтнам'}],
#    'date': '20.04.1994',
#    'stage': 'чинна',
#    'uacountry': 'В’єтнам',
#    'url': 'http://zakon2.rada.gov.ua/laws/show/704_010'}}]
